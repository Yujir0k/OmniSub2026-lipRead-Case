# %% [markdown]
# # ???????????: Pretrained VSR + LM + MediaPipe (????????)
#
# ???? ??????? ?????? ??? ??????? ??????????? ??????. ?? ???????? ????????? submission-????????.

# %%
from pathlib import Path
import json

metrics_path = Path('experiments/pretrained_vsr_lm_mediapipe/metrics_final.json')
data = json.loads(metrics_path.read_text(encoding='utf-8'))
data
